# %% [markdown]
# ## Wikipedia WordCloud
#
# What is WordCloud? <br/>
# An image composed of words used in a particular text or subject, in which the size of each word indicates its frequency or importance

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import wikipedia
import wordcloud
from wordcloud import WordCloud

# %%
rcVal = 180
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['savefig.dpi'] = rcVal
plt.rcParams['figure.dpi'] = rcVal

# %%
print('Wikipedia Version  : ',wikipedia.__version__)
print('WordCloud Version  : ',wordcloud.__version__)
print('Matplotlib Version : ',matplotlib.__version__)
# Out:
# Wikipedia Version  :  (1, 4, 0)
# WordCloud Version  :  1.4.1
# Matplotlib Version :  2.1.2

# %%
title = "Machine Learning"
summary = wikipedia.summary(title)
print(summary)
# Out:
# Machine learning is a field of computer science that gives computer systems the ability to "learn" (i.e., progressively improve performance on a specific task) with data, without being explicitly programmed.
# ...

# %%
keyword = "Machine Learning"
search_result = wikipedia.search(keyword)
print(search_result)
print(len(search_result))
# Out:
# ['Machine learning', 'Active learning (machine learning)', 'Quantum machine learning', 'Outline of machine learning', 'Adversarial machine learning', 'List of datasets for machine learning research', 'Online machine learning', 'Deep learning', 'Supervised learning', 'Weka (machine learning)']
# 10

# %%
search_result2 = wikipedia.search(keyword, results=2)
print(search_result2)
# Out:
# ['Machine learning', 'Active learning (machine learning)']

# %%
page_title = 'Machine Learning'
page = wikipedia.page(page_title)

# %%
print(page.url)
# Out:
# https://en.wikipedia.org/wiki/Machine_learning

# %%
print(page.content)
# Out:
# Machine learning is a field of computer science that gives computer systems the ability to "learn" (i.e., progressively improve performance on a specific task) with data, without being explicitly programmed.
# ...

# %%
print(page.links[:5])
# Out:
# ['ADALINE', 'AT&T Labs', 'Active learning (machine learning)', 'Adaptive website', 'Affective computing']

# %%
wcloud = WordCloud()
wcloud.generate(page.content)

# %%
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wcloud2 = WordCloud(width=1600, height=900)
wcloud2.generate(page.content)

plt.imshow(wcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wcloud3 = WordCloud(width=1600, height=900, background_color="white")
wcloud3.generate(page.content)

plt.imshow(wcloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wcloud4 = WordCloud(width=1600, height=900, background_color="white", max_font_size=50)
wcloud4.generate(page.content)

plt.imshow(wcloud4, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wcloud5 = WordCloud(width=1600, height=900, background_color="white", 
                    max_font_size=1000, font_path='data/ubuntu_condensed.ttf')
wcloud5.generate(page.content)

plt.imshow(wcloud5, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from skimage import io
import numpy as np
from wordcloud import ImageColorGenerator

coloring = io.imread('data/free-logo-flower.png')

wcloud6 = WordCloud(background_color="white",
                    font_path='data/ubuntu_condensed.ttf', mask=coloring)
wcloud6.generate(page.content)

image_colors = ImageColorGenerator(coloring)

# show
plt.imshow(wcloud6, interpolation="bilinear")
plt.axis("off")
plt.figure()

# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
plt.imshow(wcloud6.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.figure()

plt.imshow(coloring, cmap=plt.cm.gray, interpolation="bilinear")
plt.axis("off")
plt.show()
